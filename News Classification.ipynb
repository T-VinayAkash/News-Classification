# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/News.csv')

# %%
data
# Out:
#                                                 headline           category  \
# 0       There Were 2 Mass Shootings In Texas Last Wee...            CRIME
# 1       Will Smith Joins Diplo And Nicky Jam For The ...    ENTERTAINMENT
# 2       Hugh Grant Marries For The First Time At Age ...    ENTERTAINMENT
# 3       Jim Carrey Blasts 'Castrato' Adam Schiff And ...    ENTERTAINMENT
# 4       Julianna Margulies Uses Donald Trump Poop Bag...    ENTERTAINMENT
# ...                                                  ...                ...
# 20320   Police Training Fund Will Not Be Named For Ph...         POLITICS
# 20321   These States' Beauty Laws Are Stranger Than F...            STYLE
# 20322   Thank You Texas Rep. Shawn Thierry For Addres...   HEALTHY LIVING
# 20323   Science Evolution And Our Intimate Parts authors   HEALTHY LIVING
# 20324       These Days All Roads Lead To Beijing authors    THE WORLDPOST
#
#                                                  authors  \
# ...

# %%
data.head()
# Out:
#                                             headline          category  \
# 0   There Were 2 Mass Shootings In Texas Last Wee...           CRIME
# 1   Will Smith Joins Diplo And Nicky Jam For The ...   ENTERTAINMENT
# 2   Hugh Grant Marries For The First Time At Age ...   ENTERTAINMENT
# 3   Jim Carrey Blasts 'Castrato' Adam Schiff And ...   ENTERTAINMENT
# 4   Julianna Margulies Uses Donald Trump Poop Bag...   ENTERTAINMENT
#
#               authors                                  short_description
# 0   Melissa Jeltsen     She left her husband. He killed their childre...
# 1     Andy McDonald                            Of course it has a song.
# 2        Ron Dicker     The actor and his longtime girlfriend Anna Eb...
# 3        Ron Dicker     The actor gives Dems an ass-kicking for not f...
# 4        Ron Dicker     The Dietland actress said using the bags is a...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.tail()
# Out:
#                                                 headline           category  \
# 20320   Police Training Fund Will Not Be Named For Ph...         POLITICS
# 20321   These States' Beauty Laws Are Stranger Than F...            STYLE
# 20322   Thank You Texas Rep. Shawn Thierry For Addres...   HEALTHY LIVING
# 20323   Science Evolution And Our Intimate Parts authors   HEALTHY LIVING
# 20324       These Days All Roads Lead To Beijing authors    THE WORLDPOST
#
#                                                  authors  \
# 20320                                  Kaeli Subberwal
# 20321   Refinery29 ContributorThe #1 new-media brand ...
# 20322   Lynn Erdman ContributorCEO Association of Wom...
# 20323   David L. Katz M.D. M.P.H. ContributorFounder ...
# 20324                   Peter Frankopan ContributorDirec
#
#                                        short_description
# 20320   A training board rejected Minnesota Gov. Mark...
# 20321   In 2017 unless your marriage is seriously tro...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20325 entries, 0 to 20324
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   headline           20325 non-null  object
#  1   category           20325 non-null  object
#  2   authors            20325 non-null  object
#  3   short_description  20324 non-null  object
# dtypes: object(4)
# memory usage: 635.3+ KB

# %%
fig = plt.figure(figsize=(10,10))

# %%
sns.barplot(x = data['category'].value_counts().values
            ,y=data['category'].value_counts().index)
# Out:
# <Axes: >

# %%
dataf = data[['headline','category']]

# %%
dataf
# Out:
#                                                 headline           category
# 0       There Were 2 Mass Shootings In Texas Last Wee...            CRIME
# 1       Will Smith Joins Diplo And Nicky Jam For The ...    ENTERTAINMENT
# 2       Hugh Grant Marries For The First Time At Age ...    ENTERTAINMENT
# 3       Jim Carrey Blasts 'Castrato' Adam Schiff And ...    ENTERTAINMENT
# 4       Julianna Margulies Uses Donald Trump Poop Bag...    ENTERTAINMENT
# ...                                                  ...                ...
# 20320   Police Training Fund Will Not Be Named For Ph...         POLITICS
# 20321   These States' Beauty Laws Are Stranger Than F...            STYLE
# 20322   Thank You Texas Rep. Shawn Thierry For Addres...   HEALTHY LIVING
# 20323   Science Evolution And Our Intimate Parts authors   HEALTHY LIVING
# 20324       These Days All Roads Lead To Beijing authors    THE WORLDPOST
#
# [20325 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
x = np.array(dataf['headline'])
y = np.array(dataf['category'])

# %%
m = CountVectorizer()
x = m.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest =train_test_split(x,y,test_size = 0.20)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model = MultinomialNB()
model.fit(xtrain,ytrain)
# Out:
# MultinomialNB()

# %%
dataf['headline'].loc[10]
# Out:
# ' Justin Timberlake Visits Texas School Shooting Victims authors'

# %%
dataf['category'].loc[10]
# Out:
# ' ENTERTAINMENT  '

# %%
input = 'messi wins the football cup'
sport = m.transform([input]).toarray()

# %%
model.predict(sport)
# Out:
# array([' POLITICS  '], dtype='<U17')

# %%
input = 'Washington creates first statewide alert system for missing Indigenous people'
politics = m.transform([input]).toarray()

# %%
model.predict(politics)
# Out:
# array([' POLITICS  '], dtype='<U17')
